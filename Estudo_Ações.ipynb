# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import pandas_datareader.data as web

# %matplotlib inline

# %%
pip install pandas_datareader
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install yfinance --upgrade --no-cache-dir
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import yfinance as yf
yf.pdr_override()

# %%
ibov = web.get_data_yahoo('^BVSP')
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
ibov.head()
# Out:
#                  Open       High        Low      Close  Adj Close  Volume
# Date
# 1993-04-27  24.799999  25.400000  24.500000  24.500000  24.500000       0
# 1993-04-28  24.500000  24.600000  23.700001  24.299999  24.299999       0
# 1993-04-29  24.299999  24.799999  23.700001  23.700001  23.700001       0
# 1993-04-30  23.700001  24.200001  23.700001  24.100000  24.100000       0
# 1993-05-03  24.100000  24.400000  23.799999  24.100000  24.100000       0

# %%
ibov.tail()
# Out:
#                 Open      High       Low          Close      Adj Close  \
# Date
# 2021-11-25  104514.0  106400.0  104514.0  105811.000000  105811.000000
# 2021-11-26  105810.0  105810.0  101495.0  102224.000000  102224.000000
# 2021-11-29  102227.0  104149.0  102226.0  102814.000000  102814.000000
# 2021-11-30  102814.0  103066.0  100075.0  101915.000000  101915.000000
# 2021-12-01       0.0       0.0       0.0  100774.570312  100774.570312
#
#               Volume
# Date
# 2021-11-25   7890400
# 2021-11-26  10969100
# 2021-11-29  10283300
# 2021-11-30  18195100
# 2021-12-01         0

# %%
ibov['Close'].plot(figsize=(22, 8))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
import seaborn as sns

# %%
type(ibov)
# Out:
# pandas.core.frame.DataFrame

# %%
#Criar uma figura 
fig=plt.figure()

#Adicionar tamnho da figura
axes= fig.add_axes([0.5, 0.5, 2, 1.5])

#Adicionar nome dos eixos e título
axes.plot(ibov.index, ibov['Close'])
axes.set_xlabel('Data')
axes.set_ylabel('Close Price')
axes.set_title('Mercado')
# Out:
# Text(0.5, 1.0, 'Mercado')

# %%
ibov_2011 = ibov[ibov.index.year >= 2011]

# %%
#Criar uma figura 
fig=plt.figure()

#Adicionar tamnho da figura
axes= fig.add_axes([0.5, 0.5, 2, 1.5])

#partição do Gráfico
axes.grid(True)

#Adicionar nome dos eixos e título
axes.plot(ibov_2011.index, ibov_2011['Close'], 'r')
axes.set_xlabel('Data')
axes.set_ylabel('Close Price')
axes.set_title('Mercado')
# Out:
# Text(0.5, 1.0, 'Mercado')

# %%
sns.pairplot(ibov)

# %%
ibov['new'] =ibov['Close'] - ibov['Open']

# %%
ibov.drop('new', axis=1)
# Out:
#                      Open           High            Low          Close  \
# Date
# 1993-04-27      24.799999      25.400000      24.500000      24.500000
# 1993-04-28      24.500000      24.600000      23.700001      24.299999
# 1993-04-29      24.299999      24.799999      23.700001      23.700001
# 1993-04-30      23.700001      24.200001      23.700001      24.100000
# 1993-05-03      24.100000      24.400000      23.799999      24.100000
# ...                   ...            ...            ...            ...
# 2021-11-25  104514.000000  106400.000000  104514.000000  105811.000000
# 2021-11-26  105810.000000  105810.000000  101495.000000  102224.000000
# 2021-11-29  102227.000000  104149.000000  102226.000000  102814.000000
# 2021-11-30  102814.000000  103066.000000  100075.000000  101915.000000
# 2021-12-01       0.000000       0.000000       0.000000  100774.570312
#
#                 Adj Close    Volume
# Date
# 1993-04-27      24.500000         0
# ...

# %%
ibov_2011['Close'].hist()
# Out:
# <AxesSubplot:>

# %%
vale3 = web.get_data_yahoo('VALE3.SA')
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
vale3_2011 = vale3[(vale3.index.day == 15) & (vale3.index.year>=2011)].tail()

# %%
vale3_2011
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2021-04-15  108.660004  109.879997  107.550003  108.209999   96.128853
# 2021-06-15  113.769997  113.860001  111.250000  111.500000   99.051537
# 2021-07-15  114.989998  116.160004  114.500000  115.480003  104.613091
# 2021-09-15   93.879997   94.440002   91.739998   91.739998   83.107071
# 2021-10-15   79.489998   80.949997   79.300003   80.680000   80.680000
#
#               Volume
# Date
# 2021-04-15  19378200
# 2021-06-15  20587900
# 2021-07-15  18236100
# 2021-09-15  35084400
# 2021-10-15  26927200

# %%
#Criar uma figura 
fig=plt.figure()

#Adicionar tamnho da figura
axes1= fig.add_axes([0.5, 0.5, 2, 1.5])
axes2= fig.add_axes([0.2, 0.5, 0.4, 0.3])

#partição do Gráfico
axes.grid(True)

#Adicionar nome dos eixos e título
axes1.plot(ibov_2011.index, ibov_2011['Close'], 'r')
axes1.set_xlabel('Data')
axes1.set_ylabel('Close Price')
axes1.set_title('Mercado')

axes2.plot(vale3_2011.index, vale3_2011['Close'], 'r')
axes1.set_xlabel('Data')
axes1.set_ylabel('Close Price')
axes1.set_title('Mercado')
# Out:
# Text(0.5, 1.0, 'Mercado')

# %%
fig, axes = plt.subplots(3, 3, figsize=(10, 4))

# %%
ibov_2011.tail()
# Out:
#                 Open      High       Low          Close      Adj Close  \
# Date
# 2021-11-25  104514.0  106400.0  104514.0  105811.000000  105811.000000
# 2021-11-26  105810.0  105810.0  101495.0  102224.000000  102224.000000
# 2021-11-29  102227.0  104149.0  102226.0  102814.000000  102814.000000
# 2021-11-30  102814.0  103066.0  100075.0  101915.000000  101915.000000
# 2021-12-01       0.0       0.0       0.0  100774.570312  100774.570312
#
#               Volume
# Date
# 2021-11-25   7890400
# 2021-11-26  10969100
# 2021-11-29  10283300
# 2021-11-30  18195100
# 2021-12-01         0

# %%
vale3_2011.tail()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2021-04-15  108.660004  109.879997  107.550003  108.209999   96.128853
# 2021-06-15  113.769997  113.860001  111.250000  111.500000   99.051537
# 2021-07-15  114.989998  116.160004  114.500000  115.480003  104.613091
# 2021-09-15   93.879997   94.440002   91.739998   91.739998   83.107071
# 2021-10-15   79.489998   80.949997   79.300003   80.680000   80.680000
#
#               Volume
# Date
# 2021-04-15  19378200
# 2021-06-15  20587900
# 2021-07-15  18236100
# 2021-09-15  35084400
# 2021-10-15  26927200

# %%
ibov_2011['Close'].max()
# Out:
# 130776.0

# %%
vale3_2011['Close'].max()
# Out:
# 115.4800033569336

# %%
ibov_2011.corr()
# Out:
#                Open      High       Low     Close  Adj Close    Volume
# Open       1.000000  0.999495  0.999185  0.995214   0.995214  0.577140
# High       0.999495  1.000000  0.999232  0.995900   0.995900  0.584939
# Low        0.999185  0.999232  1.000000  0.996085   0.996085  0.567857
# Close      0.995214  0.995900  0.996085  1.000000   1.000000  0.574121
# Adj Close  0.995214  0.995900  0.996085  1.000000   1.000000  0.574121
# Volume     0.577140  0.584939  0.567857  0.574121   0.574121  1.000000

# %%
sns.heatmap(ibov_2011.corr(), cmap='coolwarm', annot=True)
# Out:
# <AxesSubplot:>

# %%
ibov_2011.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2699 entries, 2011-01-03 to 2021-12-01
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Open       2699 non-null   float64
#  1   High       2699 non-null   float64
#  2   Low        2699 non-null   float64
#  3   Close      2699 non-null   float64
#  4   Adj Close  2699 non-null   float64
#  5   Volume     2699 non-null   int64
# dtypes: float64(5), int64(1)
# memory usage: 147.6 KB

# %%
ibov_2011.drop('Volume', 1)
# Out:
#                 Open      High       Low          Close      Adj Close
# Date
# 2011-01-03   69310.0   70471.0   69305.0   69962.000000   69962.000000
# 2011-01-04   69962.0   70318.0   69560.0   70318.000000   70318.000000
# 2011-01-05   70311.0   71173.0   69802.0   71091.000000   71091.000000
# 2011-01-06   71093.0   71167.0   70469.0   70579.000000   70579.000000
# 2011-01-07   70580.0   70783.0   69718.0   70057.000000   70057.000000
# ...              ...       ...       ...            ...            ...
# 2021-11-25  104514.0  106400.0  104514.0  105811.000000  105811.000000
# 2021-11-26  105810.0  105810.0  101495.0  102224.000000  102224.000000
# 2021-11-29  102227.0  104149.0  102226.0  102814.000000  102814.000000
# 2021-11-30  102814.0  103066.0  100075.0  101915.000000  101915.000000
# 2021-12-01       0.0       0.0       0.0  100774.570312  100774.570312
#
# [2699 rows x 5 columns]

# %%
ibov_2011.tail()
# Out:
#                 Open      High       Low          Close      Adj Close  \
# Date
# 2021-11-25  104514.0  106400.0  104514.0  105811.000000  105811.000000
# 2021-11-26  105810.0  105810.0  101495.0  102224.000000  102224.000000
# 2021-11-29  102227.0  104149.0  102226.0  102814.000000  102814.000000
# 2021-11-30  102814.0  103066.0  100075.0  101915.000000  101915.000000
# 2021-12-01       0.0       0.0       0.0  100774.570312  100774.570312
#
#               Volume
# Date
# 2021-11-25   7890400
# 2021-11-26  10969100
# 2021-11-29  10283300
# 2021-11-30  18195100
# 2021-12-01         0

# %%
tickers = ["^BVSP", "USDBRL=X"]
carteira = web.get_data_yahoo(tickers, start='2007-01-01')['Close']
# Out:
# [*********************100%***********************]  2 of 2 completed

# %%
carteira.tail()
# Out:
#             USDBRL=X          ^BVSP
# Date
# 2021-11-26  5.565100  102224.000000
# 2021-11-29  5.607800  102814.000000
# 2021-11-30  5.600700  101915.000000
# 2021-12-01  5.620871  100774.570312
# 2021-12-02  5.695500            NaN

# %%
carteira.plot(subplots=True, figsize=(22,15))
# Out:
# array([<AxesSubplot:xlabel='Date'>, <AxesSubplot:xlabel='Date'>],
#       dtype=object)

# %%
carteira = carteira.dropna()

# %%
carteira
# Out:
#             USDBRL=X          ^BVSP
# Date
# 2007-01-02  2.131000   45383.000000
# 2007-01-03  2.134500   44445.000000
# 2007-01-04  2.139000   44020.000000
# 2007-01-05  2.147000   42245.000000
# 2007-01-08  2.146500   42830.000000
# ...              ...            ...
# 2021-11-25  5.605200  105811.000000
# 2021-11-26  5.565100  102224.000000
# 2021-11-29  5.607800  102814.000000
# 2021-11-30  5.600700  101915.000000
# 2021-12-01  5.620871  100774.570312
#
# [3655 rows x 2 columns]

# %%
carteira.plot(subplots=True, figsize=(22,15))
# Out:
# array([<AxesSubplot:xlabel='Date'>, <AxesSubplot:xlabel='Date'>],
#       dtype=object)

# %%
carteira.columns = ["Dolar", "IBOV"]

# %%
sns.heatmap(carteira.corr() ,annot=True)
# Out:
# <AxesSubplot:>

# %%
carteira["Dolar"].rolling(252).corr(carteira["IBOV"]).plot(figsize=(22,10))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
carteira["IBOV_Dolarizado"] = (carteira["IBOV"] / carteira['Dolar'])
# Out:
# <ipython-input-81-a720f0eff0a9>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   carteira["IBOV_Dolarizado"] = (carteira["IBOV"] / carteira['Dolar'])

# %%
tickers = ["ABEV3.SA", "ITSA4.SA", "WEGE3.SA", "USIM5.SA", "VALE3.SA"]

carteira_joyce = web.get_data_yahoo(tickers, period="5y")["Adj Close"]

ibov = web.get_data_yahoo("^BVSP", period="5y")["Adj Close"]
# Out:
# [*********************100%***********************]  5 of 5 completed
# [*********************100%***********************]  1 of 1 completed

# %%
carteira_joyce.tail()
# Out:
#              ABEV3.SA   ITSA4.SA  USIM5.SA   VALE3.SA   WEGE3.SA
# Date
# 2021-11-25  17.230000  10.005671     13.82  70.500000  33.799999
# 2021-11-26  16.690001   9.806155     12.91  68.639999  32.689999
# 2021-11-29  16.340000   9.796180     13.70  69.500000  32.410000
# 2021-11-30  16.110001   9.676471     13.46  69.669998  32.200001
# 2021-12-01  15.860000        NaN     13.43  70.230003  32.490002

# %%
ibov.tail()
# Out:
# Date
# 2021-11-25    105811.000000
# 2021-11-26    102224.000000
# 2021-11-29    102814.000000
# 2021-11-30    101915.000000
# 2021-12-01    100774.570312
# Name: Adj Close, dtype: float64

# %%
sns.set()
carteira_joyce.plot(figsize=(22,8))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
carteira_joyce_normalizada = (carteira_joyce / carteira_joyce.iloc[0])*10000
carteira_joyce_normalizada
# Out:
#                 ABEV3.SA      ITSA4.SA      USIM5.SA      VALE3.SA  \
# Date
# 2016-12-01  10000.000000  10000.000000  10000.000000  10000.000000
# 2016-12-02  10048.107233  10036.717718   9875.622380  10419.129956
# 2016-12-05   9897.776294   9987.762217  10049.750525  10457.993494
# 2016-12-06  10072.159870  10208.079017   9975.124738  10599.318801
# 2016-12-07  10006.014466  10232.558079  10348.256943  10963.228703
# ...                  ...           ...           ...           ...
# 2021-11-25  11802.230363  18342.173820  37903.881348  34052.861561
# 2021-11-26  11432.341050  17976.426709  35408.040031  33154.445344
# 2021-11-29  11192.597275  17958.139965  37574.759675  33569.842248
# 2021-11-30  11035.051851  17738.692049  36916.516328  33651.954647
# 2021-12-01  10863.805831           NaN  36834.236564  33922.447968
#
#                 WEGE3.SA
# Date
# 2016-12-01  10000.000000
# 2016-12-02  10089.099235
# 2016-12-05   9910.895263
# 2016-12-06  10137.079061
# ...

# %%
carteira_joyce_normalizada.plot(figsize = (22,8))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
carteira_joyce_normalizada["Saldo"] = carteira_joyce_normalizada.sum(axis=1)

# %%
carteira_joyce_normalizada
# Out:
#                 ABEV3.SA      ITSA4.SA      USIM5.SA      VALE3.SA  \
# Date
# 2016-12-01  10000.000000  10000.000000  10000.000000  10000.000000
# 2016-12-02  10048.107233  10036.717718   9875.622380  10419.129956
# 2016-12-05   9897.776294   9987.762217  10049.750525  10457.993494
# 2016-12-06  10072.159870  10208.079017   9975.124738  10599.318801
# 2016-12-07  10006.014466  10232.558079  10348.256943  10963.228703
# ...                  ...           ...           ...           ...
# 2021-11-25  11802.230363  18342.173820  37903.881348  34052.861561
# 2021-11-26  11432.341050  17976.426709  35408.040031  33154.445344
# 2021-11-29  11192.597275  17958.139965  37574.759675  33569.842248
# 2021-11-30  11035.051851  17738.692049  36916.516328  33651.954647
# 2021-12-01  10863.805831           NaN  36834.236564  33922.447968
#
#                 WEGE3.SA          Saldo
# Date
# 2016-12-01  10000.000000   50000.000000
# 2016-12-02  10089.099235   50468.676523
# ...

# %%
ibov_normalizado  = (ibov / ibov.iloc[0])*50000

# %%
ibov_normalizado
# Out:
# Date
# 2016-12-01    50000.000000
# 2016-12-02    50679.751962
# 2016-12-05    50273.077117
# 2016-12-06    51328.415144
# 2016-12-07    51602.332499
#                   ...
# 2021-11-25    88906.347152
# 2021-11-26    85892.416018
# 2021-11-29    86388.156015
# 2021-11-30    85632.782698
# 2021-12-01    84674.551156
# Name: Adj Close, Length: 1236, dtype: float64

# %%
carteira_joyce_normalizada['Saldo'].plot(figsize=(18,8), label="Minha Carteira")
ibov_normalizado.plot(label="IBOV")
plt.legend()

# %%
ibov.max()
# Out:
# 130776.0

# %%
ibov
# Out:
# Date
# 2016-12-01     59507.000000
# 2016-12-02     60316.000000
# 2016-12-05     59832.000000
# 2016-12-06     61088.000000
# 2016-12-07     61414.000000
#                   ...
# 2021-11-25    105811.000000
# 2021-11-26    102224.000000
# 2021-11-29    102814.000000
# 2021-11-30    101915.000000
# 2021-12-01    100774.570312
# Name: Adj Close, Length: 1236, dtype: float64

# %%
tickers_ibov = "ABEV3.SA AZUL4.SA B3SA3.SA BBAS3.SA BBDC3.SA BBDC4.SA BBSE3.SA BPAC11.SA BRAP4.SA BRDT3.SA BRFS3.SA BRKM5.SA BRML3.SA BTOW3.SA CCRO3.SA CIEL3.SA CMIG4.SA COGN3.SA CRFB3.SA CSAN3.SA CSNA3.SA CVCB3.SA CYRE3.SA ECOR3.SA EGIE3.SA ELET3.SA ELET6.SA EMBR3.SA ENBR3.SA EQTL3.SA FLRY3.SA GGBR4.SA GNDI3.SA GOAU4.SA GOLL4.SA HAPV3.SA HGTX3.SA HYPE3.SA IGTA3.SA IRBR3.SA ITSA4.SA ITUB4.SA JBSS3.SA KLBN11.SA LAME4.SA LREN3.SA MGLU3.SA MRFG3.SA MRVE3.SA MULT3.SA NTCO3.SA PCAR4.SA PETR3.SA PETR4.SA QUAL3.SA RADL3.SA RAIL3.SA RENT3.SA SANB11.SA SBSP3.SA SMLS3.SA SULA11.SA SUZB3.SA TAEE11.SA TIMP3.SA TOTS3.SA UGPA3.SA USIM5.SA VALE3.SA VIVT4.SA VVAR3.SA WEGE3.SA YDUQ3.SA"

ativos_yahoo = yf.download(tickers_ibov, period='1y')['Adj Close']

ibov = yf.download("BOVA11.SA", period='10y')['Adj Close']
# Out:
# [*********************100%***********************]  73 of 73 completed
#
# 7 Failed downloads:
# - HGTX3.SA: No data found, symbol may be delisted
# - BTOW3.SA: No data found, symbol may be delisted
# - PCAR4.SA: No data found, symbol may be delisted
# - VIVT4.SA: No data found, symbol may be delisted
# - TIMP3.SA: No data found, symbol may be delisted
# - SMLS3.SA: No data found, symbol may be delisted
# - VVAR3.SA: No data found, symbol may be delisted
# [*********************100%***********************]  1 of 1 completed

# %%
ativos_yahoo_norm = (ativos_yahoo / ativos_yahoo.iloc[0])*10000

# %%
ativos_yahoo_norm
# Out:
#                 ABEV3.SA      AZUL4.SA      B3SA3.SA      BBAS3.SA  \
# Date
# 2020-12-01  10000.000000  10000.000000  10000.000000  10000.000000
# 2020-12-02  10136.239861  10405.752924  10496.653278  10043.115619
# 2020-12-03  10013.623718  10857.729910  10371.609897  10129.346857
# 2020-12-04  10040.871824  10785.824726  10350.475715  10342.054192
# 2020-12-07  10197.547932  10757.575980  10295.878548  10390.917225
# ...                  ...           ...           ...           ...
# 2021-11-25  12104.810839   6972.265171   6870.402124   9827.052582
# 2021-11-26  11725.438464   5983.564473   6542.711070   9502.676666
# 2021-11-29  11479.548242   6032.357627   6387.196860   9518.122914
# 2021-11-30  11317.963737   5911.659289   6165.033702   9768.356369
# 2021-12-01  11142.327386   5613.765121   6115.046860   9669.498381
#
#                 BBDC3.SA      BBDC4.SA      BBSE3.SA     BPAC11.SA  \
# Date
# 2020-12-01  10000.000000  10000.000000  10000.000000  10000.000000
# ...

# %%
ativos_yahoo_norm.corr()
# Out:
#           ABEV3.SA  AZUL4.SA  B3SA3.SA  BBAS3.SA  BBDC3.SA  BBDC4.SA  \
# ABEV3.SA  1.000000  0.140555 -0.288706  0.251618  0.459099  0.575503
# AZUL4.SA  0.140555  1.000000  0.629947  0.329408  0.753343  0.724746
# B3SA3.SA -0.288706  0.629947  1.000000  0.442453  0.574812  0.430717
# BBAS3.SA  0.251618  0.329408  0.442453  1.000000  0.584347  0.531462
# BBDC3.SA  0.459099  0.753343  0.574812  0.584347  1.000000  0.979711
# ...            ...       ...       ...       ...       ...       ...
# VALE3.SA  0.431966  0.588099  0.173786 -0.057392  0.661659  0.717453
# VIVT4.SA       NaN       NaN       NaN       NaN       NaN       NaN
# VVAR3.SA       NaN       NaN       NaN       NaN       NaN       NaN
# WEGE3.SA -0.464887 -0.061066  0.239219  0.056536 -0.355643 -0.414693
# YDUQ3.SA  0.083097  0.799917  0.809856  0.659753  0.764597  0.688864
#
#           BBSE3.SA  BPAC11.SA  BRAP4.SA  BRDT3.SA  ...  TAEE11.SA  TIMP3.SA  \
# ...

# %%
sns.heatmap(ativos_yahoo_norm.corr())
# Out:
# <AxesSubplot:>

# %%
import yfinance as yf

# %%
ibov = web.get_data_yahoo('^BVSP')
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
ibov['Close'].index
# Out:
# DatetimeIndex(['1993-04-27', '1993-04-28', '1993-04-29', '1993-04-30',
#                '1993-05-03', '1993-05-04', '1993-05-05', '1993-05-06',
#                '1993-05-07', '1993-05-10',
#                ...
#                '2021-11-18', '2021-11-19', '2021-11-22', '2021-11-23',
#                '2021-11-24', '2021-11-25', '2021-11-26', '2021-11-29',
#                '2021-11-30', '2021-12-01'],
#               dtype='datetime64[ns]', name='Date', length=7075, freq=None)

# %%
ibov['Close'].max()
# Out:
# 130776.0

# %%
ibov['Close'].index[ibov['Close'] == ibov['Close'].max()]
# Out:
# DatetimeIndex(['2021-06-07'], dtype='datetime64[ns]', name='Date', freq=None)

# %%
ibov['Close'].index[ibov['Close'] == ibov['Close'].min()]
# Out:
# DatetimeIndex(['2016-12-19'], dtype='datetime64[ns]', name='Date', freq=None)

# %%
ibov.tail()
# Out:
#                 Open      High       Low          Close      Adj Close  \
# Date
# 2021-11-25  104514.0  106400.0  104514.0  105811.000000  105811.000000
# 2021-11-26  105810.0  105810.0  101495.0  102224.000000  102224.000000
# 2021-11-29  102227.0  104149.0  102226.0  102814.000000  102814.000000
# 2021-11-30  102814.0  103066.0  100075.0  101915.000000  101915.000000
# 2021-12-01       0.0       0.0       0.0  100774.570312  100774.570312
#
#               Volume
# Date
# 2021-11-25   7890400
# 2021-11-26  10969100
# 2021-11-29  10283300
# 2021-11-30  18195100
# 2021-12-01         0

# %%
ibov.groupby('Date')

# %%
ibov
# Out:
# Date
# 2011-12-01     57.410000
# 2011-12-02     57.029999
# 2011-12-05     58.180000
# 2011-12-06     58.730000
# 2011-12-07     57.720001
#                  ...
# 2021-11-25    101.989998
# 2021-11-26     98.389999
# 2021-11-29     99.010002
# 2021-11-30     98.349998
# 2021-12-01     97.089996
# Name: Adj Close, Length: 2480, dtype: float64

# %%
ibov_dif = (ibov['Close'].sum()) - (ibov['Open'].sum())

# %%
ibov_dif
# Out:
# 164007.66938781738

# %%
ibov_max = ibov[ibov.index.year >= 2011]['Close'].max()

# %%
vale3 = web.get_data_yahoo('VALE3.SA', period='5y')
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
vale3.tail()
# Out:
#                  Open       High        Low      Close  Adj Close    Volume
# Date
# 2021-11-25  71.290001  71.290001  69.800003  70.500000  70.500000  17199200
# 2021-11-26  67.500000  69.360001  67.500000  68.639999  68.639999  22664200
# 2021-11-29  70.279999  70.599998  69.160004  69.500000  69.500000  18164000
# 2021-11-30  69.000000  71.449997  68.690002  69.669998  69.669998  27296100
# 2021-12-01   0.000000   0.000000   0.000000  70.230003  70.230003         0

# %%
dele = ['Adj Close', 'Volume']

vale3.drop(dele, axis=1, inplace=True)

# %%
vale3.rolling(20)
# Out:
# Rolling [window=20,center=False,axis=0]
