# %%
pip install investpy
# Out:
# ...
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#
# ...
#   Created wheel for investpy: filename=investpy-1.0.7-py3-none-any.whl size=4495221 sha256=37467260da1eddb81aa3a34b4ef536bcfdcaadf6088554b38e8251decf809975
#   Stored in directory: c:\users\usuarw\appdata\local\pip\cache\wheels\75\2b\57\45c6babd0824ed333bc00bdf347454ead77906e83e2a1da0d5
# Successfully built investpy
# ...

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import investpy as inv

# %%
fundos_br = inv.get_funds_list(country='brazil')
fundos_br
# Out:
# ['Fundo De Investimento Multimercado Bordeaux Iv Crédito Privado Investimento No Exterior',
#  'Cshg Warrior V Fundo De Investimento Multimercado - Crédito Privado Investimento No Exterior',
#  'A3 Viking Fi Em Quotas De Fi Multimercado Crédito Privado Investimento No Exterior',
#  'Bb Espelho Multimercado Lp J. Safra Absoluto 30 Private Fic Fi',
#  'Ctm Hedge Fundo De Investimento Multimercado - Longo Prazo',
#  'Vif - Fundo De Investimento Em Cotas De Fundos De Investimento Multimercado',
#  'Fundo De Investimento Multimercado Bordeaux Iii Crédito Privado Investimento No Exterior',
#  'Bb Top Tatico Fundo De Investimento Multimercado',
#  'Epm Fundo De Investimento Multimercado Crédito Privado Investimento No Exterior',
#  'Western Asset Multitrading H Multimercado Fundo De Investimento',
#  'Concordia Phoenix Fundo De Investimento Multimercado Crédito Privado',
#  'Fundo De Investimento Multimercado Irmb Crédito Privado - Investimento No Exterior',
# ...

# %%
len(fundos_br)
# Out:
# 5200

# %%
fundos_br[:5]
# Out:
# ['Fundo De Investimento Multimercado Bordeaux Iv Crédito Privado Investimento No Exterior',
#  'Cshg Warrior V Fundo De Investimento Multimercado - Crédito Privado Investimento No Exterior',
#  'A3 Viking Fi Em Quotas De Fi Multimercado Crédito Privado Investimento No Exterior',
#  'Bb Espelho Multimercado Lp J. Safra Absoluto 30 Private Fic Fi',
#  'Ctm Hedge Fundo De Investimento Multimercado - Longo Prazo']

# %%
pesq = inv.search_funds(by='name', value='alaska black')
pesq
# Out:
#   country                                               name      symbol  \
# 0  brazil  Alaska Black Fundo De Investimento Em Cotas De...  0P0000U9BK
# 1  brazil  Alaska Black Master Fundo De Investimento Em A...  0P0000U9BJ
# 2  brazil  Alaska Black Fundo De Investimento Em Cotas De...  0P00019LLR
# 3  brazil  Alaska Black Institucional Fundo De Investimen...  0P00019X6E
# 4  brazil  Alfa Alaska Black Institucional - Fundo De Inv...  0P0001CF6A
#
#                         issuer          isin asset_class currency underlying
# 0   Alaska Investimentos LTDA.  BRSKP7CTF008       other      BRL
# 1   Alaska Investimentos LTDA.  BRSKI1CTF000       other      BRL
# 2   Alaska Investimentos LTDA.  BRALK5CTF006      equity      BRL
# 3   Alaska Investimentos LTDA.  BRASK4CTF002      equity      BRL
# 4  Banco Alfa Investimentos SA  BRLSK1CTF005      equity      BRL

# %%
pesq['name'][0]
# Out:
# 'Alaska Black Fundo De Investimento Em Cotas De Fundos De Investimento Em Ações - Bdr Nível I'

# %%
fundo = 'Alaska Black Fundo De Investimento Em Cotas De Fundos De Investimento Em Ações - Bdr Nível I'
alaska = inv.get_fund_historical_data(fundo, country='brazil', from_date='01/01/1900', to_date='03/12/2021')['Close']
alaska
# Out:
# Date
# 2011-01-25    0.999
# 2011-01-26    0.991
# 2011-01-27    0.977
# 2011-01-28    0.956
# 2011-01-31    0.953
#               ...
# 2021-11-25    2.046
# 2021-11-26    1.936
# 2021-11-29    1.970
# 2021-11-30    1.941
# 2021-12-01    1.915
# Name: Close, Length: 2707, dtype: float64

# %%
alaska.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
pesq2 = inv.search_funds(by='name', value='ip parti')
pesq2
# Out:
#   country                                               name      symbol  \
# 0  brazil  Ip Participações Master Fundo De Investimento ...  0P0000U6BB
# 1  brazil  Ip Participações Ipg Fundo De Investimento Em ...  0P0000U6PB
# 2  brazil  Ip Participações Fundo De Investimento Em Cota...  0P0000U6B9
#
#                                             issuer          isin asset_class  \
# 0  Investidor Profissional Gestão de Recursos Ltda  BRIPP5CTF009      equity
# 1  Investidor Profissional Gestão de Recursos Ltda  BRORM2CTF009      equity
# 2  Investidor Profissional Gestão de Recursos Ltda  BRIPPTCTF007      equity
#
#   currency underlying
# 0      BRL
# 1      BRL
# 2      BRL

# %%
pesq2['name'][0]
# Out:
# 'Ip Participações Master Fundo De Investimento Em Ações Bdr Nível I'

# %%
fundo2 = 'Ip Participações Master Fundo De Investimento Em Ações Bdr Nível I'
ipparti = inv.get_fund_historical_data(fundo2, country='brazil', from_date='01/01/1900', to_date='03/12/2021')['Close']
ipparti
# Out:
# Date
# 2017-06-29    319.307
# 2017-06-30    322.186
# 2017-07-03    321.960
# 2017-07-04    321.900
# 2017-07-05    322.452
#                ...
# 2021-11-25    768.975
# 2021-11-26    746.217
# 2021-11-29    753.911
# 2021-11-30    732.638
# 2021-12-01    713.778
# Name: Close, Length: 1089, dtype: float64

# %%
ipparti.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
inv.get_etfs_overview(country='brazil')
# Out:
#    country                                               name  \
# 0   brazil                                   Ishares Ibovespa
# 1   brazil                    It Now Ibovespa Fundo De Indice
# 2   brazil                Trend ETF MSCI ACWI Fundo de indice
# 3   brazil                      iShares BM&FBOVESPA Small Cap
# 4   brazil                              Hashdex Nasdaq Crypto
# ..     ...                                                ...
# 95  brazil  BTG Pactual ESG Fundo de indice S&P/B3 Brazil ESG
# 96  brazil           iShares ESG Aware MSCI USA Small-Cap BDR
# 97  brazil                             iShares MSCI World BDR
# 98  brazil                             iShares MSCI Spain BDR
# 99  brazil                         iShares MSCI Hong Kong BDR
#
#                                             full_name  symbol    last  change  \
# 0                                    Ishares Ibovespa  BOVA11  100.62  +0.19%
# ...

# %%
bova11 = inv.get_etf_historical_data('Ishares Ibovespa', country='brazil', from_date='01/01/1900', to_date='03/12/2021')['Close']
bova11
# Out:
# Date
# 2008-12-03     35.31
# 2008-12-04     35.70
# 2008-12-05     35.35
# 2008-12-08     38.46
# 2008-12-09     37.54
#                ...
# 2021-11-29     99.01
# 2021-11-30     98.35
# 2021-12-01     97.09
# 2021-12-02    100.43
# 2021-12-03    100.85
# Name: Close, Length: 3214, dtype: float64

# %%
bova11.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
comparativo = pd.DataFrame()
data_inicio = ipparti.index[0]

comparativo['ip'] = ipparti / ipparti.loc[data_inicio]
comparativo['alaska'] = alaska / alaska.loc[data_inicio]
comparativo['bova11'] = bova11 / bova11.loc[data_inicio]

comparativo
# Out:
#                   ip    alaska    bova11
# Date
# 2017-06-29  1.000000  1.000000  1.000000
# 2017-06-30  1.009016  1.017791  1.013810
# 2017-07-03  1.008309  1.042945  1.016473
# 2017-07-04  1.008121  1.028834  1.017471
# 2017-07-05  1.009849  1.022699  1.015807
# ...              ...       ...       ...
# 2021-11-25  2.408262  1.255215  1.697005
# 2021-11-26  2.336989  1.187730  1.637105
# 2021-11-29  2.361085  1.208589  1.647421
# 2021-11-30  2.294463  1.190798  1.636439
# 2021-12-01  2.235397  1.174847  1.615474
#
# [1089 rows x 3 columns]

# %%
comparativo.plot()
# Out:
# <AxesSubplot:xlabel='Date'>
